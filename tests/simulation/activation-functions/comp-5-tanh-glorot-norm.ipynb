# %%
import tensorflow as tf
import keras
import math

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import time
import pickle as pkl

# %%
seed = 4
np.random.seed(seed)

cell_time = np.random.uniform(-2 * np.pi, 2 * np.pi, [1000, 1])

gene01_phase = np.random.uniform(0, 2 * np.pi, [1, 500])
gene01_time = np.random.normal(0, 0.1, [1, 500])
gene01_speed = np.random.uniform(0.5, 1.5, [1, 500])

gene0_phase = np.random.uniform(0, 2 * np.pi, [1, 800])

gene1_time = np.random.normal(0, 0.1, [1, 500])
gene1_speed = np.random.uniform(0.5, 1.5, [1, 500])

gene0 = np.sin(cell_time - gene0_phase)
gene1 = np.tanh(gene1_speed * (cell_time - gene1_time))
gene01 = np.sin(cell_time - gene01_phase) + np.tanh(gene01_speed * (cell_time - gene01_time))

for i in range(10):
    plt.scatter(x=cell_time, y=gene0[:, i], s=1)

# %%
gene0.shape
# Out:
# (1000, 800)

# %%
y = keras.Input(shape=(gene0.shape[1],), name='input')
x = keras.layers.Dense(units=50, 
                       kernel_regularizer=keras.regularizers.l2(0.0001),
                       kernel_initializer=keras.initializers.glorot_normal(seed=2018)
                      )(y)
x = keras.layers.Activation(activation='tanh')(x)

x = keras.layers.Dense(units=30,
                       kernel_regularizer=keras.regularizers.l2(0.0001),
                       kernel_initializer=keras.initializers.glorot_normal(seed=2019)
                      )(x)
x = keras.layers.Activation(activation='tanh')(x)

x = keras.layers.Dense(units=1, 
                       use_bias=False, 
                       kernel_regularizer=keras.regularizers.l2(0.00001),
                       kernel_initializer=keras.initializers.glorot_normal(seed=2020),
                       name='neck'
                      )(x)

x0 = keras.layers.Lambda(lambda x: keras.backend.sin(x), name='phase0')(x)
x1 = keras.layers.Lambda(lambda x: keras.backend.sin(x + math.pi * 1 / 5), name='phase1')(x)
x2 = keras.layers.Lambda(lambda x: keras.backend.sin(x + math.pi * 2 / 5), name='phase2')(x)
x3 = keras.layers.Lambda(lambda x: keras.backend.sin(x + math.pi * 3 / 5), name='phase3')(x)
x4 = keras.layers.Lambda(lambda x: keras.backend.sin(x + math.pi * 4 / 5), name='phase4')(x)
x = keras.layers.Concatenate(name='stack')([x0, x1, x2, x3, x4])

x = keras.layers.Dense(gene0.shape[1], 
                       use_bias=False,
                       kernel_regularizer=None,
                       kernel_initializer=keras.initializers.Zeros(),
                       name='reconstructed'
                       )(x)

model = keras.Model(outputs=x, inputs=y)

# %%
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
SVG(model_to_dot(model, show_shapes=True).create(prog='dot', format='svg'))

# %%
model.compile(loss='mean_squared_error', 
              optimizer=keras.optimizers.Adam(1e-3))

class MyCallback(keras.callbacks.Callback):
    def __init__(self, interval = 100):
        self.cnt = 0
        self.interval = interval
        self.start_time = 0
        self.rec = {'time': [], 'loss': []}
    
    def on_train_begin(self, logs=None):
        self.start_time = time.time()
    
    def on_epoch_end(self, batch, logs={}):
        self.cnt += 1
        self.rec['time'].append(time.time() - self.start_time)
        self.rec['loss'].append(logs.get('loss'))
        if self.cnt % self.interval == 0:
            print(f'epoch: {self.cnt}/{self.params["epochs"]}, loss: {logs.get("loss") : .4f}, total train time: {self.rec["time"][-1] : .2f}s')

my_callback = MyCallback()
history = model.fit(gene0, gene0, epochs=3000, verbose=0, callbacks=[my_callback])
# Out:
# epoch: 100/3000, loss:  0.0152, total train time:  11.55s
# epoch: 200/3000, loss:  0.0062, total train time:  21.82s
# epoch: 300/3000, loss:  0.0090, total train time:  32.84s
# epoch: 400/3000, loss:  0.0059, total train time:  43.93s
# epoch: 500/3000, loss:  0.0095, total train time:  54.54s
# epoch: 600/3000, loss:  0.0058, total train time:  65.26s
# epoch: 700/3000, loss:  0.0067, total train time:  75.84s
# epoch: 800/3000, loss:  0.0040, total train time:  87.01s
# epoch: 900/3000, loss:  0.0088, total train time:  98.34s
# epoch: 1000/3000, loss:  0.0096, total train time:  109.68s
# epoch: 1100/3000, loss:  0.0023, total train time:  121.00s
# epoch: 1200/3000, loss:  0.0101, total train time:  132.36s
# epoch: 1300/3000, loss:  0.0037, total train time:  143.76s
# epoch: 1400/3000, loss:  0.0067, total train time:  154.96s
# epoch: 1500/3000, loss:  0.0041, total train time:  166.46s
# epoch: 1600/3000, loss:  0.0083, total train time:  177.88s
# epoch: 1700/3000, loss:  0.0041, total train time:  189.08s
# epoch: 1800/3000, loss:  0.0028, total train time:  200.12s
# epoch: 1900/3000, loss:  0.0027, total train time:  211.20s
# epoch: 2000/3000, loss:  0.0027, total train time:  222.54s
# epoch: 2100/3000, loss:  0.0064, total train time:  233.76s
# epoch: 2200/3000, loss:  0.0073, total train time:  244.95s
# epoch: 2300/3000, loss:  0.0095, total train time:  256.36s
# epoch: 2400/3000, loss:  0.0056, total train time:  267.88s
# epoch: 2500/3000, loss:  0.0041, total train time:  279.19s
# epoch: 2600/3000, loss:  0.0064, total train time:  290.40s
# epoch: 2700/3000, loss:  0.0062, total train time:  301.58s
# epoch: 2800/3000, loss:  0.0036, total train time:  312.86s
# epoch: 2900/3000, loss:  0.0036, total train time:  324.36s
# epoch: 3000/3000, loss:  0.0069, total train time:  335.47s

# %%
#model.compile(loss='mean_squared_error', 
#              optimizer=keras.optimizers.Adam(1e-4, epsilon=1e-4))
#history = model.fit(gene0, gene0, epochs=5000, verbose=2)

# %%
model.evaluate(x=gene0, y=gene0)
# Out:
# 1000/1000 [==============================] - 0s 125us/step
# 0.004752778675407171

# %%
model.get_layer('neck')

# %%
res = keras.backend.function([model.layers[0].input], 
                             [model.get_layer('neck').output, model.get_layer('reconstructed').output]
                            )([gene0])

# %%
for i in range(10):
    plt.scatter(x=res[0] % (2 * np.pi), y=gene0[:, i], s=1)

# %%
plt.scatter(res[0] % (2 * np.pi), cell_time % (2 * np.pi), s = 1)

# %%
with open('comp-5-tanh-glorot-norm-seed-%d.pkl' % seed, 'wb') as file:
    pkl.dump(my_callback.rec, file)
